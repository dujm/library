# %% [markdown]
# # About
# Here, I intend to build a LLM-based engine to retrieve the txt book link for 'book of interest'.
#  - In this notebook, I first prepare an sql database.
#  - The input csv file is from "https://www.gutenberg.org/ebooks/offline_catalogs.html#xmlrdf" (Section "XML/RDF/CSV")

# %% [markdown]
# # 1. Settings

# %% [markdown]
# ### Packages

# %%
import os
import pandas as pd


# sql related
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database

# llama index
from llama_index.core import SQLDatabase

# %% [markdown]
# ### Variables

# %%
#----------------#
# variables that require changes
#----------------#
llm_model_id ="llama2"

# sql table name 
sql_table_name = 'catalog_table'

# %% [markdown]
# ### Directories

# %%
main_Dir = "../"

#----------------#
# data dir
#----------------#
data_Dir = os.path.join(main_Dir,"data")
raw_data_Dir = os.path.join(data_Dir,"raw")
processed_data_Dir = os.path.join(data_Dir,"processed")
sql_data_Dir=os.path.join(data_Dir,"sql")



#----------------#
# make dirs
#----------------#
for f in [data_Dir, raw_data_Dir, processed_data_Dir, sql_data_Dir]:
    os.makedirs(f, exist_ok=True)

# %% [markdown]
# # 2.Setup a sql database

# %% [markdown]
# ## 2.1 Preprocess data

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
filename="pg_catalog.csv"
filepath= os.path.join(raw_data_Dir, filename)
data = pd.read_csv(filepath,low_memory=False)
data.head(1)
# Out:
#    Text#  Type      Issued                                              Title  \
# 0      1  Text  1971-12-01  The Declaration of Independence of the United ...
#
#   Language                       Authors  \
# 0       en  Jefferson, Thomas, 1743-1826
#
#                                             Subjects      LoCC  \
# 0  United States -- History -- Revolution, 1775-1...  E201; JK
#
#                                          Bookshelves
# 0  Politics; American Revolutionary War; United S...

# %% [markdown]
# ### Filter data

# %%
# filter <Type by 'Text'> and <Language by 'en'> and drop two columns
# then drop some columns
drop_cols= ['Issued','LoCC','Type','Language']
df = data.query('Type=="Text" & Language=="en"').drop(drop_cols, axis=1,inplace=False).drop_duplicates()
df.head(2)
# Out:
#    Text#                                              Title  \
# 0      1  The Declaration of Independence of the United ...
# 1      2  The United States Bill of Rights\r\nThe Ten Or...
#
#                         Authors  \
# 0  Jefferson, Thomas, 1743-1826
# 1                 United States
#
#                                             Subjects  \
# 0  United States -- History -- Revolution, 1775-1...
# 1  Civil rights -- United States -- Sources; Unit...
#
#                                          Bookshelves
# 0  Politics; American Revolutionary War; United S...
# 1  Politics; American Revolutionary War; United S...

# %% [markdown]
# ### Rename a column

# %%
# rename column "Text#" to "ID"
df.rename({'Text#': 'ID', 'Title': 'Book'}, axis=1, inplace=True)

# %% [markdown]
# ### Split a column entry (separated by`;`) into separated rows

# %%
# use pandas assign and explode function 
col_to_split = "Bookshelves"

# split column and drop na
df[col_to_split] = df[col_to_split].str.split(';')
df=df.explode(col_to_split).dropna(subset=[col_to_split], how='all', inplace=False)

# strip white space
df[col_to_split] = df[col_to_split].str.strip()
df= df.drop_duplicates()
df.head(2)
# Out:
#    ID                                               Book  \
# 0   1  The Declaration of Independence of the United ...
# 0   1  The Declaration of Independence of the United ...
#
#                         Authors  \
# 0  Jefferson, Thomas, 1743-1826
# 0  Jefferson, Thomas, 1743-1826
#
#                                             Subjects  \
# 0  United States -- History -- Revolution, 1775-1...
# 0  United States -- History -- Revolution, 1775-1...
#
#                   Bookshelves
# 0                    Politics
# 0  American Revolutionary War

# %% [markdown]
# ### What types of books are on the "Bookshelves"?

# %%
# collect "Boookshelves" into a sorted list 
list_Bookshelves = sorted(df[col_to_split].unique().tolist())

# %% [markdown]
# #### First, how many types?

# %%
# couont number of elements in the list
n_list = len(list_Bookshelves)
print(f'There are {n_list} categories in the column "{col_to_split}" ')
# Out:
# There are 247 categories in the column "Bookshelves"

# %% [markdown]
# #### Second, what are they?
#  * The below dataframe displays the book types alphabetically (from left to right)

# %%
# slice the list into 10 elements per row
df_Bookshelves = pd.DataFrame([list_Bookshelves[n:n+9] for n in range(0, len(list_Bookshelves), 10 )])

# display the book types alphabetically (from left to right)
df_Bookshelves
# Out:
#                                            0  \
# 0     6 Best Loved Spanish Literary Classics
# 1                         Animals-Wild-Birds
# 2                                        Art
# 3           Bestsellers, American, 1895-1923
# 4                  Buchanan's Journal of Man
# 5        Child's Own Book of Great Musicians
# 6                        Children's Religion
# 7                           Crime Nonfiction
# 8                                  Education
# 9                                  FR Poésie
# 10            Golden Days for Boys and Girls
# 11                              Horticulture
# 12                         Latter Day Saints
# 13                                  Medicine
# 14                                 Mythology
# 15                                     Opera
# 16                                    Poetry
# 17                                    Racism
# 18                             Short Stories
# 19  The American Architect and Building News
# 20                    The Botanical Magazine
# 21              The Haslemere Museum Gazette
# 22                                The Mentor
# 23                       The Strand Magazine
# 24                                   Western
#
#                                                     1  \
# 0                                           Adventure
# 1                                Animals-Wild-Insects
# 2                                   Arthurian Legends
# 3                                         Bibliomania
# 4                                            Buddhism
# 5                              Children's Anthologies
# 6                                    Children's Verse
# 7                                     Current History
# 8                                               Egypt
# 9                                 Famous Scots Series
# 10                                     Gothic Fiction
# 11                                              Humor
# 12                              Lippincott's Magazine
# 13                               Mediæval Town Series
# 14                              Napoleonic(Bookshelf)
# 15                                    Our Young Folks
# 16                        Poetry, A Magazine of Verse
# 17                                          Reference
# 18                                            Slavery
# 19                           The American Bee Journal
# 20  The Brochure Series of Architectural Illustration
# 21                                          The Idler
# 22  The Mirror of Literature, Amusement, and Instr...
# 23                               The Unpopular Review
# 24                                         Witchcraft
#
#                                            2  \
# 0                                     Africa
# 4                                           Canon Law
# 5                      Children's Instructional Books
# 6                                 Continental Monthly
# 7                                           Dew Drops
# 8                                           FR Femmes
# 9                                   Garden and Forest
# 10                                   Harvard Classics
# 11                                              Italy
# 12                               Maps and Cartography
# 13  Mrs Whittelsey's Magazine for Mothers and Daug...
# 14                                             Norway
# 15                                            Physics
# 16                                  Project Gutenberg
# 17                           Science Fiction by Women
# 18           St. Nicholas Magazine for Boys and Girls
# 19                                         The Argosy
# 20                                      The Economist
# 21                       The Journal of Negro History
# 22             The Philatelic Digital Library Project
# 23                                       US Civil War
# 24                                            Zoology
#
#                                                     7  \
# 0                                              Animal
# 1                                        Architecture
# 2   Banned Books List from the American Library As...
# 3                                            Boer War
# 4                                     Celtic Magazine
# 5                               Children's Literature
# 6                               Cookbooks and Cooking
# 7                                  Donahoe's Magazine
# 8                                    FR Illustrateurs
# 9                                             Geology
# 10                                           Hinduism
# 11                  Journal of Entomology and Zoology
# 12                             Masterpieces in Colour
# 13                                              Music
# 14                                  Notes and Queries
# 15                                         Physiology
# 16                                         Psychology
# 17                                Scientific American
# 18                                           Suffrage
# 19                               The Atlantic Monthly
# 20                                         The Galaxy
# 21                                  The Knickerbocker
# 22                                     The Scrap Book
# 23                                     United Kingdom
# 24                                               None
#
#                                        8
# 0                       Animals-Domestic
# 1                              Argentina
# 2   Banned Books from Anne Haight's list
# 3                                 Botany
# 4           Chambers's Edinburgh Journal
# 5    Children's Myths, Fairy Tales, etc.
# 6                                 Crafts
# 7             Early English Text Society
# 8                             FR Langues
# 9                                Germany
# 10                    Historical Fiction
# 11                               Judaism
# 12                           Mathematics
# 13                              Mycology
# 14          Noteworthy Trials(Bookshelf)
# 15   Pirates, Buccaneers, Corsairs, etc.
# 16                                 Punch
# 17                                Scouts
# 18                            Technology
# 19                  The Baptist Magazine
# 20                   The Girls Own Paper
# 21                         The Mayflower
# 22                           The Speaker
# 23                         United States
# 24                                  None

# %% [markdown]
# ## 2.2 Save the processed data to a csv

# %%
# output csv name
processed_filename =  f"processed_{filename}"

# output csv path
processed_filepath = os.path.join(processed_data_Dir,processed_filename)

# save to csv
df.to_csv(processed_filepath,index=False)

# %% [markdown]
# ## 2.3 Save the processed data to a database

# %%
# databse name
db_name =  filename.removesuffix('.csv') +".db"
db_path= os.path.join(sql_data_Dir,db_name)

# create a sql engine
sql_url = f'sqlite:///{db_path}'
engine = create_engine(sql_url, echo=False)

# create a sql database
if not database_exists(engine.url):
    create_database(engine.url)

# save df to db
df.to_sql(sql_table_name, con=engine)
# Out:
# 13207

# %%
#Construct a SQLDatabase Index
catalog_db = SQLDatabase(engine,
                         include_tables=[sql_table_name])
